# %% [markdown]
# # Capacidad Hospitalaria en Europa y envejecimiento de la poblacion: foco en España

# %%
import pandas as pd 
import numpy as np 
import requests
import data_utils as du

# %% [markdown]
# ## Cargando tablas

# %%
#Descargadas de la pagina Eurostat
df_bed_hosp = pd.read_csv('tps00046_page_linear.csv.gz')
df_hospitalarias_estancia = pd.read_csv('hospitalaria_estancia.tsv.gz', sep='\t')
df_gasto_sanitario = pd.read_csv('gasto_sanitario.tsv.gz', sep='\t')

# %% [markdown]
# ## Cargando JSON

# %%
#Api del Instituto Nacional de Estadistica
url = "https://servicios.ine.es/wstempus/js/ES/DATOS_TABLA/56934"
response = requests.get(url)

# %%
response.reason
# Out:
# 'OK'

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## Limpieza de la API

# %%
data = response.json()
df_population = pd.DataFrame(data)
df_population.head()
# Out:
#       COD                                             Nombre  FK_Unidad  \
# 0  ECP320  Total Nacional. Todas las edades. Total. Pobla...          3
# 1  ECP319  Total Nacional. Todas las edades. Hombres. Pob...          3
# 2  ECP318  Total Nacional. Todas las edades. Mujeres. Pob...          3
# 3  ECP317  Total Nacional. 0 años. Total. Población. Núme...          3
# 4  ECP316  Total Nacional. 0 años. Hombres. Población. Nú...          3
#
#    FK_Escala                                              Notas  \
# 0          1  [{'texto': 'https://www.ine.es/dyngs/INEbase/e...
# 1          1                                                NaN
# 2          1                                                NaN
# 3          1                                                NaN
# 4          1                                                NaN
#
#                                                 Data
# 0  [{'Fecha': 1735686000000, 'FK_TipoDato': 1, 'F...
# 1  [{'Fecha': 1735686000000, 'FK_TipoDato': 1, 'F...
# 2  [{'Fecha': 1735686000000, 'FK_TipoDato': 1, 'F...
# 3  [{'Fecha': 1735686000000, 'FK_TipoDato': 1, 'F...
# 4  [{'Fecha': 1735686000000, 'FK_TipoDato': 1, 'F...

# %%
df_long = df_population.explode("Data").reset_index(drop=True)

# %%
df_long
# Out:
#           COD                                             Nombre  FK_Unidad  \
# 0      ECP320  Total Nacional. Todas las edades. Total. Pobla...          3
# 1      ECP320  Total Nacional. Todas las edades. Total. Pobla...          3
# 2      ECP320  Total Nacional. Todas las edades. Total. Pobla...          3
# 3      ECP320  Total Nacional. Todas las edades. Total. Pobla...          3
# 4      ECP320  Total Nacional. Todas las edades. Total. Pobla...          3
# ...       ...                                                ...        ...
# 36115    ECP0  Total Nacional. 105 y más años. Mujeres. Pobla...          3
# 36116    ECP0  Total Nacional. 105 y más años. Mujeres. Pobla...          3
# 36117    ECP0  Total Nacional. 105 y más años. Mujeres. Pobla...          3
# 36118    ECP0  Total Nacional. 105 y más años. Mujeres. Pobla...          3
# 36119    ECP0  Total Nacional. 105 y más años. Mujeres. Pobla...          3
#
#        FK_Escala                                              Notas  \
# 0              1  [{'texto': 'https://www.ine.es/dyngs/INEbase/e...
# 1              1  [{'texto': 'https://www.ine.es/dyngs/INEbase/e...
# 2              1  [{'texto': 'https://www.ine.es/dyngs/INEbase/e...
# 3              1  [{'texto': 'https://www.ine.es/dyngs/INEbase/e...
# 4              1  [{'texto': 'https://www.ine.es/dyngs/INEbase/e...
# ...          ...                                                ...
# 36115          1                                                NaN
# 36116          1                                                NaN
# 36117          1                                                NaN
# 36118          1                                                NaN
# 36119          1                                                NaN
#
#                                                     Data
# 0      {'Fecha': 1735686000000, 'FK_TipoDato': 1, 'FK...
# 1      {'Fecha': 1727733600000, 'FK_TipoDato': 1, 'FK...
# 2      {'Fecha': 1719784800000, 'FK_TipoDato': 1, 'FK...
# 3      {'Fecha': 1711922400000, 'FK_TipoDato': 1, 'FK...
# 4      {'Fecha': 1704063600000, 'FK_TipoDato': 1, 'FK...
# ...                                                  ...
# 36115  {'Fecha': 1404165600000, 'FK_TipoDato': 1, 'FK...
# 36116  {'Fecha': 1388530800000, 'FK_TipoDato': 1, 'FK...
# 36117  {'Fecha': 1372629600000, 'FK_TipoDato': 1, 'FK...
# 36118  {'Fecha': 1356994800000, 'FK_TipoDato': 1, 'FK...
# 36119  {'Fecha': 1341093600000, 'FK_TipoDato': 1, 'FK...
#
# [36120 rows x 6 columns]

# %%
df_long["year"] = df_long["Data"].apply(lambda x: x["Anyo"])
df_long["population"] = df_long["Data"].apply(lambda x: x["Valor"])

# %%
def extract_sex(nombre):
    if "Hombres" in nombre:
        return "male"
    if "Mujeres" in nombre:
        return "female"
    return "total"

df_long["sex"] = df_long["Nombre"].apply(extract_sex)

# %%
import re

def extract_age(nombre):
    if "Todas las edades" in nombre:
        return "all"
    m = re.search(r"(\d+)\s+años", nombre)
    if m:
        return int(m.group(1))
    if "y más años" in nombre:
        m = re.search(r"(\d+)", nombre)
        if m:
            return f"{m.group(1)}+"
    return None

df_long["age"] = df_long["Nombre"].apply(extract_age)

# %%
df_pop = df_long[["year", "age", "sex", "population"]]

# %%
df_pop
# Out:
#        year   age     sex  population
# 0      2025   all   total  49128297.0
# 1      2024   all   total  48999880.0
# 2      2024   all   total  48821936.0
# 3      2024   all   total  48701130.0
# 4      2024   all   total  48619695.0
# ...     ...   ...     ...         ...
# 36115  2014  105+  female       534.0
# 36116  2014  105+  female       581.0
# 36117  2013  105+  female       602.0
# 36118  2013  105+  female       683.0
# 36119  2012  105+  female       703.0
#
# [36120 rows x 4 columns]

# %%
df_pop_sorted = df_pop.sort_values(["year"], ascending=False)

df_pop_year = (
    df_pop_sorted
    .groupby(["year", "age", "sex"], as_index=False)
    .first()
)

# %%
import numpy as np

def age_to_num(x):
    if x == "all":
        return np.nan
    if isinstance(x, str) and "+" in x:
        return int(x.replace("+", ""))
    return x

df_pop_year["age_num"] = df_pop_year["age"].apply(age_to_num)

# %%
df_pop_year
# Out:
#        year  age     sex  population  age_num
# 0      1971    0  female    314740.0      0.0
# 1      1971    0    male    334877.0      0.0
# 2      1971    0   total    647443.0      0.0
# 3      1971    2  female    308660.0      2.0
# 4      1971    2    male    324917.0      2.0
# ...     ...  ...     ...         ...      ...
# 16747  2025  85+    male    528961.0     85.0
# 16748  2025  85+   total   1566850.0     85.0
# 16749  2025  all  female  25037928.0      NaN
# 16750  2025  all    male  24090369.0      NaN
# 16751  2025  all   total  49128297.0      NaN
#
# [16752 rows x 5 columns]

# %%
pop_total = df_pop_year[
    (df_pop_year["age"] == "all") &
    (df_pop_year["sex"] == "total")
][["year", "population"]].rename(columns={"population": "pop_total"})

# %%
pop_65 = (
    df_pop_year[
        (df_pop_year["sex"] == "total") &
        (df_pop_year["age_num"] >= 65)
    ]
    .groupby("year", as_index=False)["population"]
    .sum()
    .rename(columns={"population": "pop_65"})
)

# %%
pop_65
# Out:
#     year      pop_65
# 0   1971   3288136.0
# 1   1972   3341575.0
# 2   1973   3452071.0
# 3   1974   3571638.0
# 4   1975   3616290.0
# 5   1976   3745923.0
# 6   1977   3839150.0
# 7   1978   3975840.0
# 8   1979   4055568.0
# 9   1980   4155148.0
# 10  1981   4519563.0
# 11  1982   4606950.0
# 12  1983   4702982.0
# 13  1984   4793888.0
# 14  1985   4892148.0
# 15  1986   5025425.0
# 16  1987   5165137.0
# 17  1988   5342891.0
# 18  1989   5515019.0
# 19  1990   5664907.0
# 20  1991   5856218.0
# 21  1992   5989074.0
# 22  1993   6148469.0
# 23  1994   6349268.0
# 24  1995   6532162.0
# 25  1996   6727481.0
# 26  1997   6898501.0
# 27  1998   7053774.0
# 28  1999   7228011.0
# 29  2000   7405872.0
# 30  2001   7537516.0
# 31  2002   7688923.0
# 32  2003   7825588.0
# 33  2004   7875854.0
# 34  2005   7940269.0
# 35  2006   8133940.0
# 36  2007   8301313.0
# 37  2008   8337709.0
# 38  2009   8656087.0
# 39  2010   8875292.0
# 40  2011   9059593.0
# 41  2012   9356200.0
# 42  2013   9436165.0
# 43  2014   9635336.0
# 44  2015   9828776.0
# 45  2016  10003620.0
# 46  2017  10152842.0
# 47  2018  10417027.0
# 48  2019  10619018.0
# 49  2020  10817087.0
# 50  2021  10986513.0
# 51  2022  11168785.0
# 52  2023  11383279.0
# 53  2024  11599714.0
# 54  2025  11762513.0

# %%
df_demo = pop_total.merge(pop_65, on="year")

df_demo["pct_65_plus"] = df_demo["pop_65"] / df_demo["pop_total"] * 100

# %%
df_demo
# Out:
#     year   pop_total      pop_65  pct_65_plus
# 0   1971  34040642.0   3288136.0     9.659442
# 1   1972  34595886.0   3341575.0     9.658880
# 2   1973  34980317.0   3452071.0     9.868610
# 3   1974  35363890.0   3571638.0    10.099675
# 4   1975  35569375.0   3616290.0    10.166864
# 5   1976  35946425.0   3745923.0    10.420850
# 6   1977  36506811.0   3839150.0    10.516257
# 7   1978  36694077.0   3975840.0    10.835100
# 8   1979  37035719.0   4055568.0    10.950423
# 9   1980  37346940.0   4155148.0    11.125806
# 10  1981  37764458.0   4519563.0    11.967769
# 11  1982  37987108.0   4606950.0    12.127667
# 12  1983  38090151.0   4702982.0    12.346977
# 13  1984  38325244.0   4793888.0    12.508434
# 14  1985  38467025.0   4892148.0    12.717771
# 15  1986  38571941.0   5025425.0    13.028707
# 16  1987  38682322.0   5165137.0    13.352707
# 17  1988  38731578.0   5342891.0    13.794664
# 18  1989  38821377.0   5515019.0    14.206140
# 19  1990  38860827.0   5664907.0    14.577423
# 20  1991  38881416.0   5856218.0    15.061741
# 21  1992  39051336.0   5989074.0    15.336413
# 22  1993  39264034.0   6148469.0    15.659290
# 23  1994  39547353.0   6349268.0    16.054849
# 24  1995  39718895.0   6532162.0    16.445981
# 25  1996  39808374.0   6727481.0    16.899663
# 26  1997  40049974.0   6898501.0    17.224733
# 27  1998  40214066.0   7053774.0    17.540564
# 28  1999  40303568.0   7228011.0    17.933923
# 29  2000  40470182.0   7405872.0    18.299577
# 30  2001  40665545.0   7537516.0    18.535387
# 31  2002  41423520.0   7688923.0    18.561733
# 32  2003  41827836.0   7825588.0    18.709043
# 33  2004  42547454.0   7875854.0    18.510753
# 34  2005  43662613.0   7940269.0    18.185510
# 35  2006  44360521.0   8133940.0    18.335988
# 36  2007  44784659.0   8301313.0    18.536064
# 37  2008  45668938.0   8337709.0    18.256849
# 38  2009  46239271.0   8656087.0    18.720206
# 39  2010  46562483.0   8875292.0    19.061037
# 40  2011  46667175.0   9059593.0    19.413202
# 41  2012  46749303.0   9356200.0    20.013560
# 42  2013  46712650.0   9436165.0    20.200449
# 43  2014  46495744.0   9635336.0    20.723049
# 44  2015  46425722.0   9828776.0    21.170971
# 45  2016  46427100.0  10003620.0    21.546941
# 46  2017  46497393.0  10152842.0    21.835293
# 47  2018  46715383.0  10417027.0    22.298922
# 48  2019  46918951.0  10619018.0    22.632684
# 49  2020  47344852.0  10817087.0    22.847441
# 50  2021  47424595.0  10986513.0    23.166277
# 51  2022  47609145.0  11168785.0    23.459327
# 52  2023  48085361.0  11383279.0    23.673065
# 53  2024  48999880.0  11599714.0    23.672944
# 54  2025  49128297.0  11762513.0    23.942440

# %%
pop_total = df_pop_year[
    (df_pop_year["age"] == "all") &
    (df_pop_year["sex"] == "total")
]

# %%
pop_65 = df_pop_year[
    (df_pop_year["sex"] == "total") &
    (df_pop_year["age"].apply(lambda x: isinstance(x, int) and x >= 65))
].groupby("year", as_index=False)["population"].sum()

# %%
pop_total
# Out:
#        year  age    sex  population
# 257    1971  all  total  34040642.0
# 515    1972  all  total  34595886.0
# 773    1973  all  total  34980317.0
# 1031   1974  all  total  35363890.0
# 1289   1975  all  total  35569375.0
# 1547   1976  all  total  35946425.0
# 1805   1977  all  total  36506811.0
# 2063   1978  all  total  36694077.0
# 2321   1979  all  total  37035719.0
# 2579   1980  all  total  37346940.0
# 2885   1981  all  total  37764458.0
# 3191   1982  all  total  37987108.0
# 3497   1983  all  total  38090151.0
# 3803   1984  all  total  38325244.0
# 4109   1985  all  total  38467025.0
# 4415   1986  all  total  38571941.0
# 4721   1987  all  total  38682322.0
# 5027   1988  all  total  38731578.0
# 5333   1989  all  total  38821377.0
# 5639   1990  all  total  38860827.0
# 5945   1991  all  total  38881416.0
# 6251   1992  all  total  39051336.0
# 6557   1993  all  total  39264034.0
# 6863   1994  all  total  39547353.0
# 7169   1995  all  total  39718895.0
# 7475   1996  all  total  39808374.0
# 7781   1997  all  total  40049974.0
# 8087   1998  all  total  40214066.0
# 8393   1999  all  total  40303568.0
# 8699   2000  all  total  40470182.0
# 9005   2001  all  total  40665545.0
# 9326   2002  all  total  41423520.0
# 9647   2003  all  total  41827836.0
# 9968   2004  all  total  42547454.0
# 10289  2005  all  total  43662613.0
# 10610  2006  all  total  44360521.0
# 10931  2007  all  total  44784659.0
# 11252  2008  all  total  45668938.0
# 11573  2009  all  total  46239271.0
# 11894  2010  all  total  46562483.0
# 12215  2011  all  total  46667175.0
# 12539  2012  all  total  46749303.0
# 12863  2013  all  total  46712650.0
# 13187  2014  all  total  46495744.0
# 13511  2015  all  total  46425722.0
# 13835  2016  all  total  46427100.0
# 14159  2017  all  total  46497393.0
# 14483  2018  all  total  46715383.0
# 14807  2019  all  total  46918951.0
# 15131  2020  all  total  47344852.0
# 15455  2021  all  total  47424595.0
# 15779  2022  all  total  47609145.0
# 16103  2023  all  total  48085361.0
# 16427  2024  all  total  48999880.0
# 16751  2025  all  total  49128297.0

# %%
# voy a hacer esto porque los datos completos aparecen en la columna data al abrir la api y la primera fila que contiene todos los datos
texto = df_population.loc[0, "Nombre"] # aqui selcciono la primera fila con todo el textou

mask = df_population["Nombre"].str.contains(
    texto,
    na=False
)

total_row = df_population[mask].iloc[0]
df_pop_total = pd.DataFrame(total_row["Data"])
df_pop_total.head()
# Out:
#            Fecha  FK_TipoDato  FK_Periodo  Anyo       Valor  Secreto
# 0  1735686000000            1          19  2025  49128297.0    False
# 1  1727733600000            1          22  2024  48999880.0    False
# 2  1719784800000            1          21  2024  48821936.0    False
# 3  1711922400000            1          20  2024  48701130.0    False
# 4  1704063600000            1          19  2024  48619695.0    False

# %%
#arreglare la columna fecha porque los datos en un año son trismestrales y quiero quedarme con la mas reciente de ese año
df_pop_total['Fecha'] = pd.to_datetime(df_pop_total['Fecha'], unit='ms')
df_pop_total = df_pop_total.sort_values("Fecha")

# %%
# Y ahora solo quiero quedarme con el ultimo valor de ese año
df_pop_total = df_pop_total.groupby("Anyo").tail(1)

# %%
#Renombrare las columnas con las que voy a trabajar que serian 
df_pop_total = df_pop_total.rename(columns={
    "Anyo" : "year",
    "Valor" : "population"
})

# %%
df_pop_total = df_pop_total[['year', 'population']]

# %%
#me quedo con los datos despues del 2000, porque no siempre estan los datos completos antes del 2000
#muchos paises entran mas tarde en la union europea 
df_pop_total = df_pop_total[df_pop_total["year"] >= 2000]

# %% [markdown]
# ## Limpieza de la tabla bed_hospital

# %%
du.show_total_info(df_bed_hosp,2)
# Out:
# HEAD:
#               DATAFLOW        LAST UPDATE    freq  \
# 0  ESTAT:TPS00046(1.0)  15/07/25 11:00:00  Annual
# 1  ESTAT:TPS00046(1.0)  15/07/25 11:00:00  Annual
#
#                                unit                            facility  \
# 0  Per hundred thousand inhabitants  Available beds in hospitals (HP.1)
# 1  Per hundred thousand inhabitants  Available beds in hospitals (HP.1)
#
#   hlthcare      geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  CONF_STATUS
# 0    Total  Albania         2013     288.97      NaN          NaN
# 1    Total  Austria         2013     731.76      NaN          NaN
# INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATAFLOW     404 non-null    object
#  1   LAST UPDATE  404 non-null    object
#  2   freq         404 non-null    object
#  3   unit         404 non-null    object
#  4   facility     404 non-null    object
#  5   hlthcare     404 non-null    object
#  6   geo          404 non-null    object
#  7   TIME_PERIOD  404 non-null    int64
#  8   OBS_VALUE    404 non-null    float64
#  9   OBS_FLAG     46 non-null     object
#  10  CONF_STATUS  0 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 34.8+ KB
#
# DESCRIBE:
#        TIME_PERIOD   OBS_VALUE  CONF_STATUS
# count   404.000000  404.000000          0.0
# mean   2018.034653  472.819629          NaN
# std       3.173836  170.877254          NaN
# min    2013.000000  101.620000          NaN
# 25%    2015.000000  321.802500          NaN
# 50%    2018.000000  446.480000          NaN
# 75%    2021.000000  600.797500          NaN
# max    2024.000000  864.390000          NaN
# SHAPE:
# (404, 11)

# %%
#unidades beds per hundred thousand inhabitants (100.000 habitantes)
df_bed_hosp.head()
# Out:
#               DATAFLOW        LAST UPDATE    freq  \
# 0  ESTAT:TPS00046(1.0)  15/07/25 11:00:00  Annual
# 1  ESTAT:TPS00046(1.0)  15/07/25 11:00:00  Annual
# 2  ESTAT:TPS00046(1.0)  15/07/25 11:00:00  Annual
# 3  ESTAT:TPS00046(1.0)  15/07/25 11:00:00  Annual
# 4  ESTAT:TPS00046(1.0)  15/07/25 11:00:00  Annual
#
#                                unit                            facility  \
# 0  Per hundred thousand inhabitants  Available beds in hospitals (HP.1)
# 1  Per hundred thousand inhabitants  Available beds in hospitals (HP.1)
# 2  Per hundred thousand inhabitants  Available beds in hospitals (HP.1)
# 3  Per hundred thousand inhabitants  Available beds in hospitals (HP.1)
# 4  Per hundred thousand inhabitants  Available beds in hospitals (HP.1)
#
#   hlthcare      geo  TIME_PERIOD  OBS_VALUE OBS_FLAG  CONF_STATUS
# 0    Total  Albania         2013     288.97      NaN          NaN
# 1    Total  Austria         2013     731.76      NaN          NaN
# 2    Total  Austria         2014     731.65      NaN          NaN
# 3    Total  Austria         2015     735.29      NaN          NaN
# 4    Total  Austria         2016     731.91      NaN          NaN

# %%
# me quedare solo con geo -> que me da el pais(UE), TIME_PERIOD -> año de referencia, y OBS_VALUE -> numero de camas por cada 100.000 habitantes
df_bed_hosp = df_bed_hosp[[
    'geo', 
    'TIME_PERIOD',
    'OBS_VALUE'
]]

# %%
#cambiando nombre de columnas, para mejorar el entendimiento de los valores 
df_bed_hosp = df_bed_hosp.rename(columns= {
    'geo': 'country',
    "TIME_PERIOD": "year",
    "OBS_VALUE": "beds_per_100k"
})

# %%
du.show_total_info(df_bed_hosp, 2)
# Out:
# HEAD:
#    country  year  beds_per_100k
# 0  Albania  2013         288.97
# 1  Austria  2013         731.76
# INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country        404 non-null    object
#  1   year           404 non-null    int64
#  2   beds_per_100k  404 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.6+ KB
#
# DESCRIBE:
#               year  beds_per_100k
# count   404.000000     404.000000
# mean   2018.034653     472.819629
# std       3.173836     170.877254
# min    2013.000000     101.620000
# 25%    2015.000000     321.802500
# 50%    2018.000000     446.480000
# 75%    2021.000000     600.797500
# max    2024.000000     864.390000
# SHAPE:
# (404, 3)

# %%
#cambiando tipos de datos a columna de beds_per_100k
df_bed_hosp["beds_per_100k"] = pd.to_numeric(df_bed_hosp["beds_per_100k"], errors="coerce")

# %%
df_bed_hosp
# Out:
#      country  year  beds_per_100k
# 0    Albania  2013         288.97
# 1    Austria  2013         731.76
# 2    Austria  2014         731.65
# 3    Austria  2015         735.29
# 4    Austria  2016         731.91
# ..       ...   ...            ...
# 399  Türkiye  2019         287.61
# 400  Türkiye  2020         301.23
# 401  Türkiye  2021         302.44
# 402  Türkiye  2022         308.53
# 403  Türkiye  2023         312.44
#
# [404 rows x 3 columns]

# %%
df_bed_hosp['country'].value_counts()
# Out:
# country
# Belgium                                      12
# Italy                                        11
# Norway                                       11
# Lithuania                                    11
# Luxembourg                                   11
# Latvia                                       11
# Montenegro                                   11
# Malta                                        11
# Netherlands                                  11
# Poland                                       11
# Austria                                      11
# Portugal                                     11
# Romania                                      11
# Serbia                                       11
# Sweden                                       11
# Slovenia                                     11
# Slovakia                                     11
# Liechtenstein                                11
# Türkiye                                      11
# Iceland                                      11
# Ireland                                      11
# Bulgaria                                     11
# Switzerland                                  11
# Cyprus                                       11
# Czechia                                      11
# Germany                                      11
# Estonia                                      11
# Greece                                       11
# Spain                                        11
# European Union - 27 countries (from 2020)    11
# Finland                                      11
# France                                       11
# Croatia                                      11
# Hungary                                      11
# Denmark                                      10
# North Macedonia                               9
# Moldova                                       9
# Albania                                       1
# Name: count, dtype: int64

# %% [markdown]
# ### Limpieza tabla estancia hospitalarias

# %%
#viendo los nombres de columnas, vamos a arreglarlo 
df_hospitalarias_estancia.columns
# Out:
# Index(['freq,hlthcare,indic_he,unit,geo\TIME_PERIOD', '1960 ', '1961 ',
#        '1962 ', '1963 ', '1964 ', '1965 ', '1966 ', '1967 ', '1968 ', '1969 ',
#        '1970 ', '1971 ', '1972 ', '1973 ', '1974 ', '1975 ', '1976 ', '1977 ',
#        '1978 ', '1979 ', '1980 ', '1981 ', '1982 ', '1983 ', '1984 ', '1985 ',
#        '1986 ', '1987 ', '1988 ', '1989 ', '1990 ', '1991 ', '1992 ', '1993 ',
#        '1994 ', '1995 ', '1996 ', '1997 ', '1998 ', '1999 ', '2000 ', '2001 ',
#        '2002 ', '2003 ', '2004 ', '2005 ', '2006 ', '2007 ', '2008 ', '2009 ',
#        '2010 ', '2011 ', '2012 ', '2013 ', '2014 ', '2015 ', '2016 ', '2017 ',
#        '2018 ', '2019 ', '2020 ', '2021 ', '2022 ', '2023 ', '2024 '],
#       dtype='object')

# %%
# haciendo una copia, para ver como arreglar esto
df = df_hospitalarias_estancia.copy()

# separar la columna mal formada
first_col = df_hospitalarias_estancia.columns[0]

df[first_col].head()
# Out:
# 0    A,PSY,ALOS,NR,AT
# 1    A,PSY,ALOS,NR,BE
# 2    A,PSY,ALOS,NR,BG
# 3    A,PSY,ALOS,NR,CH
# 4    A,PSY,ALOS,NR,CY
# Name: freq,hlthcare,indic_he,unit,geo\TIME_PERIOD, dtype: object

# %%
first_col = df.columns[0]

#vamos separando loas columnas
split_cols = df[first_col].str.split(",", expand=True)
split_cols.columns = ["freq", "hlthcare", "indic_he", "unit", "geo"]

df = pd.concat(
    [split_cols, df.drop(columns=[first_col])],
    axis=1
)

# %%
df
# Out:
#     freq hlthcare indic_he unit geo 1960  1961  1962  1963  1964   ...  \
# 0      A      PSY     ALOS   NR  AT    :     :     :     :     :   ...
# 1      A      PSY     ALOS   NR  BE    :     :     :     :     :   ...
# 2      A      PSY     ALOS   NR  BG    :     :     :     :     :   ...
# 3      A      PSY     ALOS   NR  CH    :     :     :     :     :   ...
# 4      A      PSY     ALOS   NR  CY    :     :     :     :     :   ...
# ..   ...      ...      ...  ...  ..   ...   ...   ...   ...   ...  ...
# 295    A    TOTAL    DISCH   NR  SE    :     :     :     :     :   ...
# 296    A    TOTAL    DISCH   NR  SI    :     :     :     :     :   ...
# 297    A    TOTAL    DISCH   NR  SK    :     :     :     :     :   ...
# 298    A    TOTAL    DISCH   NR  TR    :     :     :     :     :   ...
# 299    A    TOTAL    DISCH   NR  UK    :     :     :     :     :   ...
#
#             2015          2016          2017          2018          2019   \
# 0          18.54         18.29         18.50         18.18         19.65
# 1              :         9.35 d        9.23 d        9.29 d        8.96 d
# 2              :             :             :             :         28.90
# 3          35.12         34.22         33.27         34.28         33.62
# 4              :             :             :             :         23.20
# ..            ...           ...           ...           ...           ...
# 295   1453812.00    1419218.00    1378167.00    1373585.00    1366639.00
# 296    346601.00     343299.00     332127.00     330273.00     328416.00
# 297    934836.00     956694.00     944715.00       906471 b    911401.00
# 298  13360507.00   13267188.00   13528778.00   13465409.00   13620087.00
# 299   8191381.00    8217962.00    8242963.00    8219738.00    8125294.00
#
#             2020          2021          2022          2023  2024
# 0          18.63         18.90         17.96         19.69     :
# 1          9.38 d        9.23 d        9.49 d        9.55 d    :
# 2          32.60         32.70         32.30           32 b    :
# 3          34.21         33.69         31.85         33.94     :
# 4          24.80         28.40         31.90         33.15     :
# ..            ...           ...           ...           ...   ...
# 295   1286075.00    1310295.00    1291762.00    1267176.00     :
# 296    275693.00     286523.00       280580 b    284077.00     :
# 297    756925.00     737036.00     783468.00     814821.00     :
# 298  10486926.00   11641364.00   13113970.00   13222278.00     :
# 299            :             :             :             :     :
#
# [300 rows x 70 columns]

# %% [markdown]
# #### ALOS (Estancia media hospitalaria)

# %%
#aqui hago una copia, con solo alos (en dias)
df_alos = df[df["indic_he"] == "ALOS"].copy()

# %%
df_alos.head()
# Out:
#   freq hlthcare indic_he unit geo 1960  1961  1962  1963  1964   ...   2015   \
# 0    A      PSY     ALOS   NR  AT    :     :     :     :     :   ...  18.54
# 1    A      PSY     ALOS   NR  BE    :     :     :     :     :   ...      :
# 2    A      PSY     ALOS   NR  BG    :     :     :     :     :   ...      :
# 3    A      PSY     ALOS   NR  CH    :     :     :     :     :   ...  35.12
# 4    A      PSY     ALOS   NR  CY    :     :     :     :     :   ...      :
#
#     2016    2017    2018    2019    2020    2021    2022    2023  2024
# 0  18.29   18.50   18.18   19.65   18.63   18.90   17.96   19.69     :
# 1  9.35 d  9.23 d  9.29 d  8.96 d  9.38 d  9.23 d  9.49 d  9.55 d    :
# 2      :       :       :   28.90   32.60   32.70   32.30     32 b    :
# 3  34.22   33.27   34.28   33.62   34.21   33.69   31.85   33.94     :
# 4      :       :       :   23.20   24.80   28.40   31.90   33.15     :
#
# [5 rows x 70 columns]

# %%
df_alos.columns = df_alos.columns.str.strip()
df_alos.columns
# Out:
# Index(['freq', 'hlthcare', 'indic_he', 'unit', 'geo', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype='object')

# %%
cols_years = [c for c in df_alos.columns if c.isdigit()]
len(cols_years)
# Out:
# 65

# %%
df_alos_long = df_alos[["geo"] + cols_years].melt(
    id_vars="geo",
    var_name="year",
    value_name="avg_length_stay"
)

# %%
df_alos_long
# Out:
#      geo  year avg_length_stay
# 0     AT  1960              :
# 1     BE  1960              :
# 2     BG  1960              :
# 3     CH  1960              :
# 4     CY  1960              :
# ...   ..   ...             ...
# 6560  SE  2024              :
# 6561  SI  2024              :
# 6562  SK  2024              :
# 6563  TR  2024              :
# 6564  UK  2024              :
#
# [6565 rows x 3 columns]

# %%
df_alos_long["avg_length_stay"] = (
    df_alos_long["avg_length_stay"]
    .astype(str)
    .str.replace(":", "", regex=False)
    .str.replace(r"[a-zA-Z]", "", regex=True)
)

df_alos_long["avg_length_stay"] = pd.to_numeric(
    df_alos_long["avg_length_stay"], errors="coerce"
)

# %%
df_alos_long["year"] = df_alos_long["year"].astype(int)

# %%
df_alos_long = df_alos_long[df_alos_long["year"] >= 2013]

# %%
df_alos_long = df_alos_long.dropna(subset=["avg_length_stay"])

# %%
df_alos_long
# Out:
#      geo  year  avg_length_stay
# 5353  AT  2013            18.83
# 5356  CH  2013            36.92
# 5358  CZ  2013            11.59
# 5359  DE  2013            21.70
# 5360  EE  2013            17.70
# ...   ..   ...              ...
# 6461  SK  2023             6.60
# 6462  TR  2023             4.20
# 6477  IS  2024             9.98
# 6509  IS  2024             5.57
# 6544  IS  2024             5.87
#
# [939 rows x 3 columns]

# %% [markdown]
# ### Tabla gasto sanitario

# %%
df_gasto_sanitario.head()
# Out:
#   freq,unit,icha11_hc,geo\TIME_PERIOD 1992  1993  1994      1995      1996   \
# 0                    A,EUR_HAB,HC1,AT    :     :     :   1219.78   1251.98
# 1                    A,EUR_HAB,HC1,BA    :     :     :         :         :
# 2                    A,EUR_HAB,HC1,BE    :     :     :         :         :
# 3                    A,EUR_HAB,HC1,BG    :     :     :         :         :
# 4                    A,EUR_HAB,HC1,CH    :     :     :         :         :
#
#       1997      1998      1999      2000   ...     2015      2016      2017   \
# 0  1228.05   1271.26   1322.55   1361.18   ...  2180.87   2252.47   2321.05
# 1        :         :         :         :   ...   203.68    222.65    231.05
# 2        :         :         :         :   ...  1751.78   1726.12   1808.28
# 3        :         :         :         :   ...   245.71    264.11    290.79
# 4        :         :         :         :   ...  3844.52   3821.59   3768.69
#
#       2018      2019      2020      2021      2022      2023  2024
# 0  2418.12   2529.05   2585.27   2698.92    2801.9   3039.03     :
# 1   251.85         :         :         :    340.92    392.42     :
# 2  1879.73   1992.23   2094.52   2173.82   2284.67   2411.31     :
# 3   317.56     344.5    418.15    480.37    509.39    593.48     :
# 4  3615.78    3767.1   3824.01   3937.57   4312.67   4645.56     :
#
# [5 rows x 34 columns]

# %% [markdown]
# #### DISCH (Demanda hospitalaria)

# %%
df_disch = df[df["indic_he"] == "DISCH"].copy()

# %%
df_disch.columns = df_disch.columns.str.strip()

cols_years = [c for c in df_disch.columns if c.isdigit()]

# %%
df_disch_long = df_disch[["geo"] + cols_years].melt(
    id_vars="geo",
    var_name="year",
    value_name="hospital_discharges"
)

# %%
df_disch_long["hospital_discharges"] = (
    df_disch_long["hospital_discharges"]
    .astype(str)
    .str.replace(":", "", regex=False)
    .str.replace(r"[a-zA-Z]", "", regex=True)
)

df_disch_long["hospital_discharges"] = pd.to_numeric(
    df_disch_long["hospital_discharges"], errors="coerce"
)

df_disch_long["year"] = df_disch_long["year"].astype(int)

# %%
df_disch_long = df_disch_long[df_disch_long["year"] >= 2013]
df_disch_long = df_disch_long.dropna(subset=["hospital_discharges"])

# %%
df_disch_long
# Out:
#      geo  year  hospital_discharges
# 5353  AT  2013              85806.0
# 5356  CH  2013              70629.0
# 5358  CZ  2013              30631.0
# 5359  DE  2013            1139809.0
# 5360  EE  2013              12490.0
# ...   ..   ...                  ...
# 6461  SK  2023             814821.0
# 6462  TR  2023           13222278.0
# 6477  IS  2024               2647.0
# 6509  IS  2024              36370.0
# 6544  IS  2024              39017.0
#
# [942 rows x 3 columns]

# %%
df_disch_long.shape
df_disch_long.head()
df_disch_long["year"].min(), df_disch_long["year"].max()
# Out:
# (2013, 2024)

# %% [markdown]
# ### Limpieza de tabla gasto sanitario

# %%
df_gasto_sanitario
# Out:
#       freq,unit,icha11_hc,geo\TIME_PERIOD 1992  1993  1994      1995   \
# 0                        A,EUR_HAB,HC1,AT    :     :     :   1219.78
# 1                        A,EUR_HAB,HC1,BA    :     :     :         :
# 2                        A,EUR_HAB,HC1,BE    :     :     :         :
# 3                        A,EUR_HAB,HC1,BG    :     :     :         :
# 4                        A,EUR_HAB,HC1,CH    :     :     :         :
# ...                                   ...   ...   ...   ...       ...
# 23180                 A,PPS_HAB,TOT_HC,RS    :     :     :         :
# 23181                 A,PPS_HAB,TOT_HC,SE    :     :     :         :
# 23182                 A,PPS_HAB,TOT_HC,SI    :     :     :         :
# 23183                 A,PPS_HAB,TOT_HC,SK    :     :     :         :
# 23184                 A,PPS_HAB,TOT_HC,UK    :     :     :         :
#
#           1996      1997      1998      1999      2000   ...     2015   \
# 0      1251.98   1228.05   1271.26   1322.55   1361.18   ...  2180.87
# 1            :         :         :         :         :   ...   203.68
# 2            :         :         :         :         :   ...  1751.78
# 3            :         :         :         :         :   ...   245.71
# 4            :         :         :         :         :   ...  3844.52
# ...         ...       ...       ...       ...       ...  ...       ...
# 23180        :         :         :         :         :   ...        :
# 23181        :         :         :         :         :   ...  3683.88
# 23182        :         :         :         :         :   ...  1889.55
# 23183        :         :         :         :         :   ...   1508.5
# 23184        :         :         :         :         :   ...  2806.82
#
#           2016      2017      2018      2019      2020       2021      2022   \
# 0      2252.47   2321.05   2418.12   2529.05   2585.27    2698.92    2801.9
# 1       222.65    231.05    251.85         :         :          :    340.92
# 2      1726.12   1808.28   1879.73   1992.23   2094.52    2173.82   2284.67
# 3       264.11    290.79    317.56     344.5    418.15     480.37    509.39
# 4      3821.59   3768.69   3615.78    3767.1   3824.01    3937.57   4312.67
# ...         ...       ...       ...       ...       ...        ...       ...
# 23180        :         :         :         :         :   1399.78 b  1422.21
# 23181  3655.49   3697.64    3803.5   3855.18   3947.42    4245.29   4379.57
# 23182  1938.87   1995.24   2124.09   2286.72   2443.23    2697.45   2955.58
# 23183   1444.2   1390.76   1401.34   1519.29   1592.95    1874.62   1962.46
# 23184  2826.06    2884.3   2950.83   3062.87         :          :         :
#
#           2023  2024
# 0      3039.03     :
# 1       392.42     :
# 2      2411.31     :
# 3       593.48     :
# 4      4645.56     :
# ...         ...   ...
# 23180  1537.35     :
# 23181  4688.07     :
# 23182  3120.68     :
# 23183  2088.01     :
# 23184        :     :
#
# [23185 rows x 34 columns]

# %%
###voy a separar la columna gigante
df = df_gasto_sanitario.copy()
first_col_2 = df.columns[0]
df[first_col_2].head()
# Out:
# 0    A,EUR_HAB,HC1,AT
# 1    A,EUR_HAB,HC1,BA
# 2    A,EUR_HAB,HC1,BE
# 3    A,EUR_HAB,HC1,BG
# 4    A,EUR_HAB,HC1,CH
# Name: freq,unit,icha11_hc,geo\TIME_PERIOD, dtype: object

# %%
split_cols = df[first_col_2].str.split(",", expand=True)
split_cols.columns = ["freq", "unit", "icha11_hc", "geo"]

df = pd.concat(
    [split_cols, df.drop(columns=[first_col_2])],
    axis=1
)

# %%
df.columns = df.columns.str.strip()

# %%
df
# Out:
#       freq     unit icha11_hc geo 1992 1993 1994      1995      1996  \
# 0        A  EUR_HAB       HC1  AT   :    :    :   1219.78   1251.98
# 1        A  EUR_HAB       HC1  BA   :    :    :         :         :
# 2        A  EUR_HAB       HC1  BE   :    :    :         :         :
# 3        A  EUR_HAB       HC1  BG   :    :    :         :         :
# 4        A  EUR_HAB       HC1  CH   :    :    :         :         :
# ...    ...      ...       ...  ..  ...  ...  ...       ...       ...
# 23180    A  PPS_HAB    TOT_HC  RS   :    :    :         :         :
# 23181    A  PPS_HAB    TOT_HC  SE   :    :    :         :         :
# 23182    A  PPS_HAB    TOT_HC  SI   :    :    :         :         :
# 23183    A  PPS_HAB    TOT_HC  SK   :    :    :         :         :
# 23184    A  PPS_HAB    TOT_HC  UK   :    :    :         :         :
#
#            1997  ...      2015      2016      2017      2018      2019  \
# 0      1228.05   ...  2180.87   2252.47   2321.05   2418.12   2529.05
# 1            :   ...   203.68    222.65    231.05    251.85         :
# 2            :   ...  1751.78   1726.12   1808.28   1879.73   1992.23
# 3            :   ...   245.71    264.11    290.79    317.56     344.5
# 4            :   ...  3844.52   3821.59   3768.69   3615.78    3767.1
# ...         ...  ...       ...       ...       ...       ...       ...
# 23180        :   ...        :         :         :         :         :
# 23181        :   ...  3683.88   3655.49   3697.64    3803.5   3855.18
# 23182        :   ...  1889.55   1938.87   1995.24   2124.09   2286.72
# 23183        :   ...   1508.5    1444.2   1390.76   1401.34   1519.29
# 23184        :   ...  2806.82   2826.06    2884.3   2950.83   3062.87
#
#            2020       2021      2022      2023 2024
# 0      2585.27    2698.92    2801.9   3039.03    :
# 1            :          :    340.92    392.42    :
# 2      2094.52    2173.82   2284.67   2411.31    :
# 3       418.15     480.37    509.39    593.48    :
# 4      3824.01    3937.57   4312.67   4645.56    :
# ...         ...        ...       ...       ...  ...
# 23180        :   1399.78 b  1422.21   1537.35    :
# 23181  3947.42    4245.29   4379.57   4688.07    :
# 23182  2443.23    2697.45   2955.58   3120.68    :
# 23183  1592.95    1874.62   1962.46   2088.01    :
# 23184        :          :         :         :    :
#
# [23185 rows x 37 columns]

# %%
# TOT_HC = gasto total sanitario icha11_hc seleciono este porque mi hipotesis es gasto sanitario per capita vs estancia/demanda
# Total health care expenditure

# EUR_HAB = euros por habitante unit

# %%
#Filtrar tipo y unidad 
df = df[(df["icha11_hc"] == "TOT_HC") & (df["unit"] == "EUR_HAB")]

# %%
#Detectar columnas de años
df.columns = df.columns.str.strip()

cols_years = [c for c in df.columns if c.isdigit()]
len(cols_years)
# Out:
# 33

# %%
df_gasto_long = df[["geo"] + cols_years].melt(
    id_vars="geo",
    var_name="year",
    value_name="health_exp_pc"
)

# %%
df_gasto_long["health_exp_pc"] = (
    df_gasto_long["health_exp_pc"]
    .astype(str)
    .str.replace(":", "", regex=False)
    .str.replace(r"[a-zA-Z]", "", regex=True)
)

df_gasto_long["health_exp_pc"] = pd.to_numeric(
    df_gasto_long["health_exp_pc"], errors="coerce"
)

df_gasto_long["year"] = df_gasto_long["year"].astype(int)

# %%
df_gasto_long = df_gasto_long[df_gasto_long["year"] >= 2013]
df_gasto_long = df_gasto_long.dropna(subset=["health_exp_pc"])

# %%
df_gasto_long
# Out:
#      geo  year  health_exp_pc
# 903   AT  2013        3941.40
# 904   BA  2013         337.05
# 905   BE  2013        3761.74
# 906   BG  2013         419.48
# 907   CH  2013        6963.94
# ...   ..   ...            ...
# 1370  RO  2023         971.52
# 1371  RS  2023         911.93
# 1372  SE  2023        5728.38
# 1373  SI  2023        2804.82
# 1374  SK  2023        1677.80
#
# [410 rows x 3 columns]

# %%
country_map = {
    # EU
    "AT": "Austria",
    "BE": "Belgium",
    "BG": "Bulgaria",
    "HR": "Croatia",
    "CY": "Cyprus",
    "CZ": "Czechia",
    "DK": "Denmark",
    "EE": "Estonia",
    "FI": "Finland",
    "FR": "France",
    "DE": "Germany",
    "EL": "Greece",
    "GR": "Greece",
    "HU": "Hungary",
    "IE": "Ireland",
    "IT": "Italy",
    "LV": "Latvia",
    "LT": "Lithuania",
    "LU": "Luxembourg",
    "MT": "Malta",
    "NL": "Netherlands",
    "PL": "Poland",
    "PT": "Portugal",
    "RO": "Romania",
    "SK": "Slovakia",
    "SI": "Slovenia",
    "ES": "Spain",
    "SE": "Sweden",

    # EFTA / Western Europe
    "CH": "Switzerland",
    "NO": "Norway",
    "IS": "Iceland",
    "LI": "Liechtenstein",
    "UK": "United Kingdom",

    # Balkans & others
    "BA": "Bosnia and Herzegovina",
    "RS": "Serbia",
    "ME": "Montenegro",
    "MK": "North Macedonia",
    "AL": "Albania",
    "XK": "Kosovo",

    # Eastern Europe / neighbours
    "UA": "Ukraine",
    "MD": "Moldova",
    "BY": "Belarus",

    # Turkey
    "TR": "Türkiye",

    # Caucasus (sometimes appear)
    "GE": "Georgia",
    "AM": "Armenia",
    "AZ": "Azerbaijan",

    # Microstates (rare but appear)
    "SM": "San Marino",
    "MC": "Monaco",
    "AD": "Andorra",
    "VA": "Vatican City"
}

# %%
df_beds["country"] = df_beds["country"].map(country_map)

df_alos_long["country"] = df_alos_long["geo"].map(country_map)
df_disch_long["country"] = df_disch_long["geo"].map(country_map)
df_gasto_long["country"] = df_gasto_long["geo"].map(country_map)

# %%
df_alos_long[df_alos_long["country"].isna()]["geo"].unique()

# %% [markdown]
# #### Tabla de Sanitaria

# %%
#pip install xlrd

# %%
#!pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Downloading lxml-6.0.2-cp310-cp310-macosx_10_9_universal2.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 19.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %%
dfs = pd.read_html("Tabla-9af0d933-634f-4431-99fb-b0e777fb51d0.xls")

len(dfs)
# Out:
# 7

# %%
for i, d in enumerate(dfs):
    print("Tabla", i)
    display(d.head())
# Out:
# Tabla 0
#                                                   0   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   1   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   2   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   3   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   4   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   5   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   6   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   7   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   8   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   9   \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   10  \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   11  \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   12  \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   13  \
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
#
#                                                   14
# 0  Resumen por Comunidad Autónoma - Tipo de hospi...
# Tabla 1
#                              0                             1   \
# 0  Fecha de emisión: 02/02/2026  Fecha de emisión: 02/02/2026
#
#                              2                             3   \
# 0  Fecha de emisión: 02/02/2026  Fecha de emisión: 02/02/2026
#
#                              4                             5   \
# 0  Fecha de emisión: 02/02/2026  Fecha de emisión: 02/02/2026
#
#                              6                             7   \
# 0  Fecha de emisión: 02/02/2026  Fecha de emisión: 02/02/2026
#
#                              8                             9   \
# 0  Fecha de emisión: 02/02/2026  Fecha de emisión: 02/02/2026
#
#                              10                            11  \
# 0  Fecha de emisión: 02/02/2026  Fecha de emisión: 02/02/2026
#
#                              12                            13  \
# 0  Fecha de emisión: 02/02/2026  Fecha de emisión: 02/02/2026
#
#                              14
# 0  Fecha de emisión: 02/02/2026
# Tabla 2
#                                                   0   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   1   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   2   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   3   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   4   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   5   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   6   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   7   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   8   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   9   \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   10  \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   11  \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   12  \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   13  \
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
#
#                                                   14
# 0  Dimensiones en filas: [Temporal].[Temporal].[Año]
# Tabla 3
#                            0                           1   \
# 0  Medidas: [Número de altas]  Medidas: [Número de altas]
#
#                            2                           3   \
# 0  Medidas: [Número de altas]  Medidas: [Número de altas]
#
#                            4                           5   \
# 0  Medidas: [Número de altas]  Medidas: [Número de altas]
#
#                            6                           7   \
# 0  Medidas: [Número de altas]  Medidas: [Número de altas]
#
#                            8                           9   \
# 0  Medidas: [Número de altas]  Medidas: [Número de altas]
#
#                            10                          11  \
# 0  Medidas: [Número de altas]  Medidas: [Número de altas]
#
#                            12                          13  \
# 0  Medidas: [Número de altas]  Medidas: [Número de altas]
#
#                            14
# 0  Medidas: [Número de altas]
# Tabla 4
#   Unnamed: 0 Número de altas
# 0       1997       3.004.200
# 1       1998       3.149.124
# 2       1999       3.092.087
# 3       2000       3.238.022
# 4       2001       3.297.074
# Tabla 5
#                                                   0   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   1   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   2   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   3   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   4   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   5   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   6   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   7   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   8   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   9   \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   10  \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   11  \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   12  \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   13  \
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
#
#                                                   14
# 0  Fuente: Ministerio de Sanidad. Subdirección Ge...
# Tabla 6
#                                                   0   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   1   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   2   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   3   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   4   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   5   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   6   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   7   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   8   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   9   \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   10  \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   11  \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   12  \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   13  \
# 0  Dirección de la web: http://pestadistico.intel...
#
#                                                   14
# 0  Dirección de la web: http://pestadistico.intel...

# %%
df_altas_spain = dfs[4].copy()

# %%
df_altas_spain
# Out:
#    Unnamed: 0 Número de altas
# 0        1997       3.004.200
# 1        1998       3.149.124
# 2        1999       3.092.087
# 3        2000       3.238.022
# 4        2001       3.297.074
# 5        2002       3.343.711
# 6        2003       3.444.541
# 7        2004       3.496.238
# 8        2005       3.541.107
# 9        2006       3.589.728
# 10       2007       3.686.655
# 11       2008       3.735.945
# 12       2009       3.742.850
# 13       2010       3.711.173
# 14       2011       3.689.540
# 15       2012       3.653.895
# 16       2013       3.636.876
# 17       2014       3.681.787
# 18       2015       3.727.583
# 19       2016       3.705.836
# 20       2017       3.772.367
# 21       2018       3.819.951
# 22       2019       3.759.821
# 23       2020       3.314.044
# 24       2021       3.512.485
# 25       2022       3.691.445
# 26       2023       3.773.908
# 27       2024       3.818.348
# 28      Total      99.630.341

# %%
df_altas_spain = df_altas_spain[df_altas_spain["Unnamed: 0"] != "Total"]

# %%
df_altas_spain
# Out:
#    Unnamed: 0 Número de altas
# 0        1997       3.004.200
# 1        1998       3.149.124
# 2        1999       3.092.087
# 3        2000       3.238.022
# 4        2001       3.297.074
# 5        2002       3.343.711
# 6        2003       3.444.541
# 7        2004       3.496.238
# 8        2005       3.541.107
# 9        2006       3.589.728
# 10       2007       3.686.655
# 11       2008       3.735.945
# 12       2009       3.742.850
# 13       2010       3.711.173
# 14       2011       3.689.540
# 15       2012       3.653.895
# 16       2013       3.636.876
# 17       2014       3.681.787
# 18       2015       3.727.583
# 19       2016       3.705.836
# 20       2017       3.772.367
# 21       2018       3.819.951
# 22       2019       3.759.821
# 23       2020       3.314.044
# 24       2021       3.512.485
# 25       2022       3.691.445
# 26       2023       3.773.908
# 27       2024       3.818.348

# %%
df_altas_spain = df_altas_spain.rename(columns={'Unnamed: 0': 'year'})

# %%
df_altas_spain
# Out:
#     year Número de altas
# 0   1997       3.004.200
# 1   1998       3.149.124
# 2   1999       3.092.087
# 3   2000       3.238.022
# 4   2001       3.297.074
# 5   2002       3.343.711
# 6   2003       3.444.541
# 7   2004       3.496.238
# 8   2005       3.541.107
# 9   2006       3.589.728
# 10  2007       3.686.655
# 11  2008       3.735.945
# 12  2009       3.742.850
# 13  2010       3.711.173
# 14  2011       3.689.540
# 15  2012       3.653.895
# 16  2013       3.636.876
# 17  2014       3.681.787
# 18  2015       3.727.583
# 19  2016       3.705.836
# 20  2017       3.772.367
# 21  2018       3.819.951
# 22  2019       3.759.821
# 23  2020       3.314.044
# 24  2021       3.512.485
# 25  2022       3.691.445
# 26  2023       3.773.908
# 27  2024       3.818.348
